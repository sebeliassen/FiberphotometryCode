# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')

import numpy as np
from processing.timepoint_analysis import get_signal_around_timepoint
from analysis.response_metrics import calculate_signal_response_metrics
from data.mouse import create_mice_dict
from analysis.performance_funcs import add_performance_container

from main import load_and_prepare_sessions
from config import *


sessions = load_and_prepare_sessions("../../Baseline", load_from_pickle=True, remove_bad_signal_sessions=True)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
interval_start = peak_interval_config["interval_start"]
interval_end = peak_interval_config["interval_end"]

# %%
def find_start_end_idxs(event_type):
    fps = PLOTTING_CONFIG['fps']

    start_time, end_time = attr_interval_dict[event_type]
    start_event_idx = int(start_time * fps + interval_start)
    end_event_idx = int(end_time * fps + interval_start)

    return start_event_idx, end_event_idx

# %%
mice_dict = create_mice_dict(sessions)
for mouse in mice_dict.values():
    add_performance_container(mouse)

# %%
curr_event_type = 'hit'
curr_brain_region = 'DMS_right'

xs, all_ys = get_signal_around_timepoint(sessions[0], curr_event_type, curr_brain_region)

# %%
for ys in all_ys:
    start_event_idx, end_event_idx = find_start_end_idxs(curr_event_type)
    ys -= np.mean(ys[start_event_idx-7:start_event_idx+7])

    curr_brain_region_uni = curr_brain_region.split('_')[0]
    curr_response_metrics = calculate_signal_response_metrics(ys, (start_event_idx, end_event_idx))
    curr_response_metrics = {f'{curr_brain_region_uni}_{curr_event_type}_{k}': v for k, v in curr_response_metrics.items()}
    print(curr_response_metrics)
    print(mice_dict[sessions[0].mouse_id].metric_container.data)
# Out:
# {'DMS_hit_slope_up': 0.19989641053773574, 'DMS_hit_slope_down': 0.04620011722591361, 'DMS_hit_maximal_value': 5.697205908802397, 'DMS_hit_peak_timing': 29, 'DMS_hit_auc': 117.9288359789883}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}
# {'DMS_hit_slope_up': 0.1137453028567767, 'DMS_hit_slope_down': 0.06899061506606964, 'DMS_hit_maximal_value': 5.69835292026002, 'DMS_hit_peak_timing': 52, 'DMS_hit_auc': 89.93219799013724}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}
# {'DMS_hit_slope_up': 0.02777208417576901, 'DMS_hit_slope_down': 0.033487139377628275, 'DMS_hit_maximal_value': 1.8183954970985385, 'DMS_hit_peak_timing': 69, 'DMS_hit_auc': 8.792607495106282}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}
# {'DMS_hit_slope_up': 0.09555174878281228, 'DMS_hit_slope_down': 0.043799661869290046, 'DMS_hit_maximal_value': 4.282558444701782, 'DMS_hit_peak_timing': 47, 'DMS_hit_auc': 49.928644065408676}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}
# {'DMS_hit_slope_up': 0.07221122445513604, 'DMS_hit_slope_down': 0.04391415293966244, 'DMS_hit_maximal_value': 3.5308836029656785, 'DMS_hit_peak_timing': 53, 'DMS_hit_auc': 15.040761240618117}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}
# {'DMS_hit_slope_up': 0.036222517074127686, 'DMS_hit_slope_down': 0.0539389490470082, 'DMS_hit_maximal_value': 4.0959779143008745, 'DMS_hit_peak_timing': 73, 'DMS_hit_auc': 54.12211795358341}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}
# {'DMS_hit_slope_up': 0.14108962316618304, 'DMS_hit_slope_down': 0.055001930360988105, 'DMS_hit_maximal_value': 7.238406970367681, 'DMS_hit_peak_timing': 53, 'DMS_hit_auc': -12.365548184840556}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}
# {'DMS_hit_slope_up': 0.09663068453217258, 'DMS_hit_slope_down': 0.024774094073542283, 'DMS_hit_maximal_value': 3.609262719219603, 'DMS_hit_peak_timing': 38, 'DMS_hit_auc': 22.204994803408212}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}
# {'DMS_hit_slope_up': 0.11339836729250746, 'DMS_hit_slope_down': 0.05650706616147627, 'DMS_hit_maximal_value': 6.41332339535985, 'DMS_hit_peak_timing': 54, 'DMS_hit_auc': 131.2563444394386}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}
# {'DMS_hit_slope_up': 0.06574756240600002, 'DMS_hit_slope_down': 0.03588507273800309, 'DMS_hit_maximal_value': 3.548471111979021, 'DMS_hit_peak_timing': 53, 'DMS_hit_auc': 28.75634191081684}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}
# {'DMS_hit_slope_up': 0.23005307811831194, 'DMS_hit_slope_down': 0.10772349270552899, 'DMS_hit_maximal_value': 10.86028681561848, 'DMS_hit_peak_timing': 47, 'DMS_hit_auc': 120.06571832410673}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}
# {'DMS_hit_slope_up': 0.0477546600229216, 'DMS_hit_slope_down': 0.02681712787353628, 'DMS_hit_maximal_value': 3.134017638712816, 'DMS_hit_peak_timing': 51, 'DMS_hit_auc': -106.00526954237361}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}
# {'DMS_hit_slope_up': 0.14864092065628287, 'DMS_hit_slope_down': 0.04908253194702101, 'DMS_hit_maximal_value': 6.104777313324746, 'DMS_hit_peak_timing': 39, 'DMS_hit_auc': 38.72693017264}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}
# {'DMS_hit_slope_up': 0.13422975106354876, 'DMS_hit_slope_down': 0.07883096925259978, 'DMS_hit_maximal_value': 6.223684167739117, 'DMS_hit_peak_timing': 52, 'DMS_hit_auc': -89.34148708956181}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}
# {'DMS_hit_slope_up': 0.10715733961438796, 'DMS_hit_slope_down': 0.05617652747151152, 'DMS_hit_maximal_value': 5.021233823253716, 'DMS_hit_peak_timing': 52, 'DMS_hit_auc': -111.73420943482176}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}
# {'DMS_hit_slope_up': 0.012315993229680671, 'DMS_hit_slope_down': 0.021270019481589048, 'DMS_hit_maximal_value': 1.7388693693873454, 'DMS_hit_peak_timing': 113, 'DMS_hit_auc': -41.39755518257286}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}
# {'DMS_hit_slope_up': 0.06505613701852121, 'DMS_hit_slope_down': 0.04455193324015193, 'DMS_hit_maximal_value': 3.43185828047804, 'DMS_hit_peak_timing': 52, 'DMS_hit_auc': 7.528218531925269}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}
# {'DMS_hit_slope_up': 0.10757240786302125, 'DMS_hit_slope_down': 0.022570636566871735, 'DMS_hit_maximal_value': 3.085843157502521, 'DMS_hit_peak_timing': 31, 'DMS_hit_auc': 38.445912365585556}
# {'d_prime': 0.7062379183870319, 'c_score': 1.3446454338708465, 'participation': 57.0, 'total_hits': 36.0, 'total_mistakes': 21.0, 'hit_rate': 0.16071428571428573, 'false_alarm_rate': 0.04477611940298507}

# %%
from collections import defaultdict
from tqdm.notebook import tqdm

# %%
all_coords = defaultdict(list)

for session in tqdm(sessions):
    for curr_event_type in attr_interval_dict.keys():
        for curr_brain_region in ['DMS', 'DLS', 'VS']:
            if len(session.timepoints_container.data.get(curr_event_type, [])) == 0:
                continue

            if f'{curr_brain_region}_left' in session.brain_regions:
                xs, all_ys = get_signal_around_timepoint(session, curr_event_type, f'{curr_brain_region}_left')
            elif f'{curr_brain_region}_right' in session.brain_regions:
                xs, all_ys = get_signal_around_timepoint(session, curr_event_type, f'{curr_brain_region}_right')
            else:
                continue
                                                         
            for ys in all_ys:
                start_event_idx, end_event_idx = find_start_end_idxs(curr_event_type)
                ys -= np.mean(ys[start_event_idx-7:start_event_idx+7])

                curr_brain_region_uni = curr_brain_region.split('_')[0]
                curr_response_metrics = calculate_signal_response_metrics(ys, (start_event_idx, end_event_idx))
                curr_response_metrics = {f'{curr_brain_region_uni}_{curr_event_type}_{k}': v for k, v in curr_response_metrics.items()}

                for metric, metric_value in mice_dict[session.mouse_id].metric_container.data.items():
                    for response, response_value in curr_response_metrics.items():
                        all_coords[response + "_" + metric].append((metric_value, response_value))
# Out:
#   0%|          | 0/33 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 10
#       7     continue
#       9 if f'{curr_brain_region}_left' in session.brain_regions:
# ---> 10     xs, all_ys = get_signal_around_timepoint(session, curr_event_type, f'{curr_brain_region}_left')
#      11 elif f'{curr_brain_region}_right' in session.brain_regions:
#      12     xs, all_ys = get_signal_around_timepoint(session, curr_event_type, f'{curr_brain_region}_right')
#
# File ~/Desktop/GetherLabCode/FiberphotometryCode/project_root/notebooks/../processing/timepoint_analysis.py:37, in get_signal_around_timepoint(session, timepoint_name, brain_region)
#      34 if len(event_sync[event_sync > 0]) <= interval_end:
#      35     continue  # Skip events too close to the end of a session
# ---> 37 event_index = event_sync[event_sync > 0].idxmin()
#      39 # Ensuring the interval does not go out of bounds
#      40 start_idx = max(event_index - interval_start, 0)
#
# File ~/opt/anaconda3/envs/SUND/lib/python3.11/site-packages/pandas/core/series.py:2557, in Series.idxmin(self, axis, skipna, *args, **kwargs)
#    2552 with warnings.catch_warnings():
#    2553     # TODO(3.0): this catching/filtering can be removed
#    2554     # ignore warning produced by argmin since we will issue a different
#    2555     #  warning for idxmin
#    2556     warnings.simplefilter("ignore")
# -> 2557     i = self.argmin(axis, skipna, *args, **kwargs)
#    2559 if i == -1:
#    2560     # GH#43587 give correct NA value for Index.
#    2561     warnings.warn(
#    2562         f"The behavior of {type(self).__name__}.idxmin with all-NA "
#    2563         "values, or any-NA and skipna=False, is deprecated. In a future "
#    (...)
#    2566         stacklevel=find_stack_level(),
#    2567     )
#
# File ~/opt/anaconda3/envs/SUND/lib/python3.11/site-packages/pandas/core/base.py:785, in IndexOpsMixin.argmin(self, axis, skipna, *args, **kwargs)
#     783         return delegate.argmin()
#     784 else:
# --> 785     result = nanops.nanargmin(delegate, skipna=skipna)
#     786     if result == -1:
#     787         warnings.warn(
#     788             f"The behavior of {type(self).__name__}.argmax/argmin "
#     789             "with skipna=False and NAs, or with all-NAs is deprecated. "
#    (...)
#     792             stacklevel=find_stack_level(),
#     793         )
#
# File ~/opt/anaconda3/envs/SUND/lib/python3.11/site-packages/pandas/core/nanops.py:1186, in nanargmin(values, axis, skipna, mask)
#    1148 def nanargmin(
#    1149     values: np.ndarray,
#    1150     *,
#    (...)
#    1153     mask: npt.NDArray[np.bool_] | None = None,
#    1154 ) -> int | np.ndarray:
#    1155     """
#    1156     Parameters
#    1157     ----------
#    (...)
#    1184     array([0, 0, 1, 1])
#    1185     """
# -> 1186     values, mask = _get_values(values, True, fill_value_typ="+inf", mask=mask)
#    1187     # error: Need type annotation for 'result'
#    1188     result = values.argmin(axis)  # type: ignore[var-annotated]
#
# File ~/opt/anaconda3/envs/SUND/lib/python3.11/site-packages/pandas/core/nanops.py:294, in _get_values(values, skipna, fill_value, fill_value_typ, mask)
#     260 """
#     261 Utility to get the values view, mask, dtype, dtype_max, and fill_value.
#     262
#    (...)
#     288     Mask for values, if deemed necessary to compute
#     289 """
#     290 # In _get_values is only called from within nanops, and in all cases
#     291 #  with scalar fill_value.  This guarantee is important for the
#     292 #  np.where call below
# --> 294 mask = _maybe_get_mask(values, skipna, mask)
#     296 dtype = values.dtype
#     298 datetimelike = False
#
# File ~/opt/anaconda3/envs/SUND/lib/python3.11/site-packages/pandas/core/nanops.py:248, in _maybe_get_mask(values, skipna, mask)
#     245         return None
#     247     if skipna or values.dtype.kind in "mM":
# --> 248         mask = isna(values)
#     250 return mask
#
# File ~/opt/anaconda3/envs/SUND/lib/python3.11/site-packages/pandas/core/dtypes/missing.py:178, in isna(obj)
#     101 def isna(obj: object) -> bool | npt.NDArray[np.bool_] | NDFrame:
#     102     """
#     103     Detect missing values for an array-like object.
#     104
#    (...)
#     176     Name: 1, dtype: bool
#     177     """
# --> 178     return _isna(obj)
#
# File ~/opt/anaconda3/envs/SUND/lib/python3.11/site-packages/pandas/core/dtypes/missing.py:207, in _isna(obj, inf_as_na)
#     205     return False
#     206 elif isinstance(obj, (np.ndarray, ABCExtensionArray)):
# --> 207     return _isna_array(obj, inf_as_na=inf_as_na)
#     208 elif isinstance(obj, ABCIndex):
#     209     # Try to use cached isna, which also short-circuits for integer dtypes
#     210     #  and avoids materializing RangeIndex._values
#     211     if not obj._can_hold_na:
#
# File ~/opt/anaconda3/envs/SUND/lib/python3.11/site-packages/pandas/core/dtypes/missing.py:300, in _isna_array(values, inf_as_na)
#     298         result = ~np.isfinite(values)
#     299     else:
# --> 300         result = np.isnan(values)
#     302 return result
#
# KeyboardInterrupt:

# %%
all_coords.keys()
# Out:
# dict_keys(['DMS_hit_slope_up_d_prime', 'DMS_hit_slope_down_d_prime', 'DMS_hit_maximal_value_d_prime', 'DMS_hit_peak_timing_d_prime', 'DMS_hit_auc_d_prime', 'DMS_hit_slope_up_c_score', 'DMS_hit_slope_down_c_score', 'DMS_hit_maximal_value_c_score', 'DMS_hit_peak_timing_c_score', 'DMS_hit_auc_c_score', 'DMS_hit_slope_up_participation', 'DMS_hit_slope_down_participation', 'DMS_hit_maximal_value_participation', 'DMS_hit_peak_timing_participation', 'DMS_hit_auc_participation', 'DMS_hit_slope_up_total_hits', 'DMS_hit_slope_down_total_hits', 'DMS_hit_maximal_value_total_hits', 'DMS_hit_peak_timing_total_hits', 'DMS_hit_auc_total_hits', 'DMS_hit_slope_up_total_mistakes', 'DMS_hit_slope_down_total_mistakes', 'DMS_hit_maximal_value_total_mistakes', 'DMS_hit_peak_timing_total_mistakes', 'DMS_hit_auc_total_mistakes', 'DMS_hit_slope_up_hit_rate', 'DMS_hit_slope_down_hit_rate', 'DMS_hit_maximal_value_hit_rate', 'DMS_hit_peak_timing_hit_rate', 'DMS_hit_auc_hit_rate', 'DMS_hit_slope_up_false_alarm_rate', 'DMS_hit_slope_down_false_alarm_rate', 'DMS_hit_maximal_value_false_alarm_rate', 'DMS_hit_peak_timing_false_alarm_rate', 'DMS_hit_auc_false_alarm_rate', 'DLS_hit_slope_up_d_prime', 'DLS_hit_slope_down_d_prime', 'DLS_hit_maximal_value_d_prime', 'DLS_hit_peak_timing_d_prime', 'DLS_hit_auc_d_prime', 'DLS_hit_slope_up_c_score', 'DLS_hit_slope_down_c_score', 'DLS_hit_maximal_value_c_score', 'DLS_hit_peak_timing_c_score', 'DLS_hit_auc_c_score', 'DLS_hit_slope_up_participation', 'DLS_hit_slope_down_participation', 'DLS_hit_maximal_value_participation', 'DLS_hit_peak_timing_participation', 'DLS_hit_auc_participation', 'DLS_hit_slope_up_total_hits', 'DLS_hit_slope_down_total_hits', 'DLS_hit_maximal_value_total_hits', 'DLS_hit_peak_timing_total_hits', 'DLS_hit_auc_total_hits', 'DLS_hit_slope_up_total_mistakes', 'DLS_hit_slope_down_total_mistakes', 'DLS_hit_maximal_value_total_mistakes', 'DLS_hit_peak_timing_total_mistakes', 'DLS_hit_auc_total_mistakes', 'DLS_hit_slope_up_hit_rate', 'DLS_hit_slope_down_hit_rate', 'DLS_hit_maximal_value_hit_rate', 'DLS_hit_peak_timing_hit_rate', 'DLS_hit_auc_hit_rate', 'DLS_hit_slope_up_false_alarm_rate', 'DLS_hit_slope_down_false_alarm_rate', 'DLS_hit_maximal_value_false_alarm_rate', 'DLS_hit_peak_timing_false_alarm_rate', 'DLS_hit_auc_false_alarm_rate', 'DMS_miss_slope_up_d_prime', 'DMS_miss_slope_down_d_prime', 'DMS_miss_maximal_value_d_prime', 'DMS_miss_peak_timing_d_prime', 'DMS_miss_auc_d_prime', 'DMS_miss_slope_up_c_score', 'DMS_miss_slope_down_c_score', 'DMS_miss_maximal_value_c_score', 'DMS_miss_peak_timing_c_score', 'DMS_miss_auc_c_score', 'DMS_miss_slope_up_participation', 'DMS_miss_slope_down_participation', 'DMS_miss_maximal_value_participation', 'DMS_miss_peak_timing_participation', 'DMS_miss_auc_participation', 'DMS_miss_slope_up_total_hits', 'DMS_miss_slope_down_total_hits', 'DMS_miss_maximal_value_total_hits', 'DMS_miss_peak_timing_total_hits', 'DMS_miss_auc_total_hits', 'DMS_miss_slope_up_total_mistakes', 'DMS_miss_slope_down_total_mistakes', 'DMS_miss_maximal_value_total_mistakes', 'DMS_miss_peak_timing_total_mistakes', 'DMS_miss_auc_total_mistakes', 'DMS_miss_slope_up_hit_rate', 'DMS_miss_slope_down_hit_rate', 'DMS_miss_maximal_value_hit_rate', 'DMS_miss_peak_timing_hit_rate', 'DMS_miss_auc_hit_rate', 'DMS_miss_slope_up_false_alarm_rate', 'DMS_miss_slope_down_false_alarm_rate', 'DMS_miss_maximal_value_false_alarm_rate', 'DMS_miss_peak_timing_false_alarm_rate', 'DMS_miss_auc_false_alarm_rate', 'DLS_miss_slope_up_d_prime', 'DLS_miss_slope_down_d_prime', 'DLS_miss_maximal_value_d_prime', 'DLS_miss_peak_timing_d_prime', 'DLS_miss_auc_d_prime', 'DLS_miss_slope_up_c_score', 'DLS_miss_slope_down_c_score', 'DLS_miss_maximal_value_c_score', 'DLS_miss_peak_timing_c_score', 'DLS_miss_auc_c_score', 'DLS_miss_slope_up_participation', 'DLS_miss_slope_down_participation', 'DLS_miss_maximal_value_participation', 'DLS_miss_peak_timing_participation', 'DLS_miss_auc_participation', 'DLS_miss_slope_up_total_hits', 'DLS_mi ...

# %%
import pandas as pd
from scipy.stats import pearsonr
import numpy as np

# Initialize a list to hold all rows before creating the DataFrame
data = []

for metric_pair, values in all_coords.items():
    # Convert values to a pandas DataFrame for easier handling
    df_values = pd.DataFrame(values, columns=['Metric Values', 'Response Values'])
    
    # Remove NaN and Inf values
    df_values.replace([np.inf, -np.inf], np.nan, inplace=True)  # Replace Inf with NaN
    df_values.dropna(inplace=True)  # Drop all rows with NaN
    
    if df_values.shape[0] > 1:  # Ensure there are at least two data points for correlation
        correlation, p_value = pearsonr(df_values['Metric Values'], df_values['Response Values'])
        
        # Append the results to the data list
        data.append({
            "Metric Pair": metric_pair,
            "Pearson Correlation": correlation,
            "P-Value": p_value,
            "Number of Coordinates": len(df_values)
        })

# Create a DataFrame from the data list
df = pd.DataFrame(data)

# Set the 'Metric Pair' column as the index
df.set_index("Metric Pair", inplace=True)

# Sort the DataFrame ascendingly by p-value
df_sorted = df.sort_values(by="P-Value", ascending=True)

# Display the sorted DataFrame
df_sorted
# Out:
#                                                     Pearson Correlation  \
# Metric Pair
# DLS_cor_reject_maximal_value_false_alarm_rate                 -0.220260
# DLS_cor_reject_maximal_value_total_mistakes                   -0.217623
# VS_before_dispimg_hit_maximal_value_total_mistakes             0.351741
# VS_before_dispimg_hit_maximal_value_false_alarm...             0.326479
# DLS_before_dispimg_mistake_maximal_value_false_...            -0.492151
# ...                                                                 ...
# VS_mistake_slope_down_participation                            0.000903
# DMS_reward_collect_slope_down_false_alarm_rate                -0.000703
# DLS_before_dispimg_mistake_peak_timing_false_al...            -0.000841
# DLS_before_dispimg_mistake_peak_timing_c_score                 0.000448
# DLS_before_dispimg_hit_slope_down_d_prime                     -0.000282
#
#                                                          P-Value  \
# Metric Pair
# DLS_cor_reject_maximal_value_false_alarm_rate       4.994553e-43
# DLS_cor_reject_maximal_value_total_mistakes         5.072863e-42
# VS_before_dispimg_hit_maximal_value_total_mistakes  2.631637e-24
# VS_before_dispimg_hit_maximal_value_false_alarm...  5.604246e-21
# DLS_before_dispimg_mistake_maximal_value_false_...  1.692389e-20
# ...                                                          ...
# VS_mistake_slope_down_participation                 9.839532e-01
# DMS_reward_collect_slope_down_false_alarm_rate      9.839749e-01
# DLS_before_dispimg_mistake_peak_timing_false_al...  9.881821e-01
# DLS_before_dispimg_mistake_peak_timing_c_score      9.936997e-01
# DLS_before_dispimg_hit_slope_down_d_prime           9.945054e-01
#
#                                                     Number of Coordinates
# Metric Pair
# DLS_cor_reject_maximal_value_false_alarm_rate                        3805
# DLS_cor_reject_maximal_value_total_mistakes                          3805
# VS_before_dispimg_hit_maximal_value_total_mistakes                    786
# VS_before_dispimg_hit_maximal_value_false_alarm...                    786
# DLS_before_dispimg_mistake_maximal_value_false_...                    313
# ...                                                                   ...
# VS_mistake_slope_down_participation                                   499
# DMS_reward_collect_slope_down_false_alarm_rate                        818
# DLS_before_dispimg_mistake_peak_timing_false_al...                    313
# DLS_before_dispimg_mistake_peak_timing_c_score                        313
# DLS_before_dispimg_hit_slope_down_d_prime                             599
#
# [735 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
for k in all_coords.keys():
        plt.title(k)
        plt.scatter(*zip(*all_coords[k]))
        plt.show()

# %%
# Set pandas options to display all rows
pd.set_option('display.max_rows', None)

# Display the DataFrame
display(df_sorted)
# Out:
#                                                    Pearson Correlation  \
# Metric Pair
# DLS_cor_reject_maximal_value_false_alarm_rate                -0.220260
# DLS_cor_reject_maximal_value_total_mistakes                  -0.217623
# VS_hit_maximal_value_total_mistakes                           0.320514
# DLS_mistake_maximal_value_false_alarm_rate                   -0.476458
# DLS_mistake_maximal_value_total_mistakes                     -0.474262
# VS_reward_collect_maximal_value_total_mistakes                0.303916
# VS_hit_maximal_value_false_alarm_rate                         0.293988
# VS_reward_collect_peak_timing_participation                  -0.293200
# DLS_cor_reject_maximal_value_d_prime                          0.130641
# VS_reward_collect_maximal_value_false_alarm_rate              0.276574
# DLS_hit_maximal_value_d_prime                                 0.307787
# DLS_miss_maximal_value_false_alarm_rate                      -0.210614
# DLS_miss_maximal_value_total_mistakes                        -0.208499
# VS_hit_maximal_value_participation                            0.262284
# VS_reward_collect_peak_timing_c_score                         0.261897
# VS_reward_collect_peak_timing_total_hits                     -0.257899
# VS_reward_collect_maximal_value_participation                 0.257523
# DLS_cor_reject_maximal_value_participation                   -0.117197
# DMS_reward_collect_auc_total_hits                             0.247455
# DLS_mistake_maximal_value_d_prime                             0.382189
# DMS_reward_collect_auc_hit_rate                               0.232653
# VS_miss_maximal_value_total_hits                              0.195761
# VS_reward_collect_peak_timing_hit_rate                       -0.231450
# VS_miss_auc_total_hits                                        0.193347
# VS_reward_collect_peak_timing_total_mistakes                 -0.230440
# VS_miss_maximal_value_hit_rate                                0.187901
# DMS_reward_collect_auc_participation                          0.219255
# DMS_reward_collect_auc_c_score                               -0.218325
# VS_hit_auc_participation                                      0.219197
# DLS_mistake_maximal_value_participation                      -0.340688
# DMS_hit_auc_c_score                                          -0.213611
# VS_hit_auc_total_mistakes                                     0.217023
# DLS_hit_maximal_value_total_mistakes                         -0.246691
# DLS_hit_maximal_value_false_alarm_rate                       -0.246469
# DLS_reward_collect_maximal_value_d_prime                      0.245516
# VS_reward_collect_peak_timing_false_alarm_rate               -0.212439
# DMS_hit_auc_participation                                     0.206306
# DMS_hit_auc_total_hits                                        0.202387
# DMS_hit_auc_hit_rate                                          0.201241
# VS_cor_reject_slope_down_total_hits                          -0.093778
# DLS_mistake_maximal_value_c_score                             0.316635
# VS_cor_reject_slope_down_d_prime                             -0.092071
# VS_mistake_maximal_value_false_alarm_rate                     0.248840
# VS_miss_maximal_value_participation                           0.166778
# VS_miss_auc_hit_rate                                          0.166687
# DMS_miss_peak_timing_participation                           -0.151067
# VS_hit_maximal_value_c_score                                 -0.197316
# VS_mistake_maximal_value_total_mistakes                       0.245640
# VS_miss_maximal_value_d_prime                                 0.164312
# DMS_miss_peak_timing_c_score                                  0.147461
# VS_reward_collect_maximal_value_c_score                      -0.192044
# VS_hit_auc_false_alarm_rate                                   0.191793
# DMS_miss_maximal_value_hit_rate                               0.145697
# DMS_miss_peak_timing_total_hits                              -0.144503
# DLS_cor_reject_maximal_value_c_score                          0.086696
# DMS_miss_maximal_value_participation                          0.143045
# DMS_miss_maximal_value_c_score                               -0.142974
# DMS_miss_peak_timing_total_mistakes                          -0.140686
# VS_miss_auc_d_prime                                           0.155077
# DMS_miss_maximal_value_total_hits                             0.140380
# DMS_miss_peak_timing_hit_rate                                -0.139068
# VS_cor_reject_slope_down_hit_rate                            -0.082536
# VS_cor_reject_peak_timing_total_hits                         -0.082423
# DMS_miss_peak_timing_false_alarm_rate                        -0.136338
# VS_cor_reject_peak_timing_d_prime                            -0.082033
# DMS_reward_collect_auc_d_prime                                0.171464
# VS_hit_auc_c_score                                           -0.173248
# VS_reward_collect_auc_participation                           0.173094
# DMS_miss_maximal_value_false_alarm_rate                       0.130717
# VS_hit_peak_timing_participation                             -0.171355
# DMS_hit_auc_total_mistakes                                    0.166780
# VS_hit_peak_timing_total_hits                                -0.168766
# DMS_hit_auc_false_alarm_rate                                  0.165233
# DMS_miss_maximal_value_total_mistakes                         0.127619
# DLS_miss_maximal_value_d_prime                                0.130136
# DMS_miss_maximal_value_d_prime                                0.126432
# VS_miss_auc_participation                                     0.136597
# VS_mistake_maximal_value_participation                        0.201996
# VS_miss_maximal_value_c_score                                -0.133744
# DLS_miss_peak_timing_d_prime                                 -0.123079
# VS_cor_reject_peak_timing_hit_rate                           -0.071795
# DLS_reward_collect_maximal_value_total_hits                   0.179616
# DLS_hit_maximal_value_total_hits                              0.176444
# VS_cor_reject_maximal_value_total_mistakes                    0.070107
# VS_cor_reject_maximal_value_false_alarm_rate                  0.069498
# DMS_miss_peak_timing_d_prime                                 -0.114255
# DLS_miss_peak_timing_total_hits                              -0.116635
# VS_mistake_maximal_value_c_score                             -0.187118
# DLS_reward_collect_peak_timing_total_mistakes                 0.170771
# DLS_reward_collect_peak_timing_false_alarm_rate               0.170403
# VS_miss_auc_c_score                                          -0.123462
# VS_hit_auc_total_hits                                         0.145704
# DLS_miss_maximal_value_participation                         -0.112945
# DMS_reward_collect_auc_total_mistakes                         0.142045
# VS_cor_reject_maximal_value_d_prime                          -0.065843
# VS_hit_peak_timing_hit_rate                                  -0.144251
# VS_reward_collect_auc_total_mistakes                          0.144163
# VS_reward_collect_auc_total_hits                              0.143663
# DMS_cor_reject_peak_timing_d_prime                           -0.060848
# VS_reward_collect_slope_down_hit_rate                        -0.142754
# VS_hit_maximal_value_d_prime                                 -0.142203
# DMS_reward_collect_maximal_value_total_hits                   0.139036
# DLS_miss_peak_timing_hit_rate                                -0.109575
# DLS_cor_reject_slope_down_false_alarm_rate                   -0.064022
# DMS_cor_reject_peak_timing_total_hits                        -0.059727
# DMS_reward_collect_auc_false_alarm_rate                       0.137420
# VS_hit_slope_down_total_hits                                 -0.139491
# VS_reward_collect_auc_c_score                                -0.139475
# DLS_cor_reject_slope_down_total_mistakes                     -0.062878
# VS_hit_slope_down_d_prime                                    -0.137166
# VS_reward_collect_slope_down_d_prime                         -0.135579
# VS_cor_reject_slope_down_c_score                              0.061392
# DMS_miss_slope_up_d_prime                                     0.102141
# VS_hit_peak_timing_c_score                                    0.133278
# DLS_cor_reject_peak_timing_d_prime                           -0.060599
# DMS_miss_slope_up_total_hits                                  0.101426
# DMS_reward_collect_maximal_value_participation                0.129033
# DLS_reward_collect_maximal_value_hit_rate                     0.148661
# VS_reward_collect_slope_down_total_hits                      -0.128806
# VS_mistake_auc_false_alarm_rate                               0.159153
# DMS_miss_slope_up_hit_rate                                    0.096306
# VS_hit_slope_up_total_mistakes                                0.125432
# DMS_hit_maximal_value_participation                           0.122043
# VS_reward_collect_auc_false_alarm_rate                        0.124158
# DLS_reward_collect_maximal_value_false_alarm_rate            -0.140905
# DMS_hit_maximal_value_total_hits                              0.120384
# DLS_reward_collect_maximal_value_total_mistakes              -0.140646
# VS_cor_reject_peak_timing_participation                      -0.055871
# VS_hit_slope_down_hit_rate                                   -0.122520
# DLS_cor_reject_peak_timing_total_hits                        -0.055774
# VS_mistake_auc_total_mistakes                                 0.152012
# VS_reward_collect_maximal_value_d_prime                      -0.120206
# DLS_miss_peak_timing_c_score                                  0.093270
# DMS_miss_slope_up_participation                               0.091425
# DMS_cor_reject_slope_up_d_prime                               0.051121
# VS_reward_collect_maximal_value_total_hits                    0.119119
# DLS_hit_slope_down_hit_rate                                   0.135650
# DMS_cor_reject_peak_timing_hit_rate                          -0.050349
# DMS_reward_collect_maximal_value_hit_rate                     0.115615
# DLS_cor_reject_peak_timing_hit_rate                          -0.053608
# VS_hit_peak_timing_total_mistakes                            -0.117732
# DMS_miss_slope_up_c_score                                    -0.089697
# DMS_miss_auc_participation                                    0.088750
# DLS_hit_maximal_value_hit_rate                                0.133016
# DLS_cor_reject_slope_up_d_prime                               0.053343
# VS_cor_reject_maximal_value_total_hits                       -0.052724
# DLS_hit_slope_down_total_hits                                 0.131289
# VS_mistake_auc_c_score                                       -0.142898
# DMS_cor_reject_peak_timing_participation                     -0.048304
# DMS_miss_auc_total_hits                                       0.085498
# DMS_cor_reject_peak_timing_c_score                            0.047687
# DLS_miss_maximal_value_c_score                                0.087166
# VS_reward_collect_slope_down_c_score                          0.110336
# VS_hit_maximal_value_total_hits                               0.110067
# DLS_reward_collect_peak_timing_participation                  0.126069
# VS_cor_reject_slope_down_participation                       -0.049928
# DMS_miss_auc_hit_rate                                         0.082676
# VS_reward_collect_auc_hit_rate                                0.108983
# DLS_cor_reject_slope_down_participation                      -0.049329
# VS_hit_auc_hit_rate                                           0.108015
# DMS_miss_auc_total_mistakes                                   0.081697
# DLS_miss_peak_timing_participation                           -0.083215
# DMS_reward_collect_maximal_value_c_score                     -0.104780
# VS_hit_slope_up_false_alarm_rate                              0.106928
# VS_miss_maximal_value_total_mistakes                          0.089202
# VS_mistake_auc_participation                                  0.133640
# DLS_hit_slope_down_c_score                                   -0.120739
# VS_reward_collect_maximal_value_hit_rate                      0.105490
# VS_cor_reject_peak_timing_c_score                             0.047687
# DMS_miss_auc_false_alarm_rate                                 0.078562
# DLS_hit_slope_down_participation                              0.118391
# DLS_reward_collect_auc_total_hits                             0.117725
# DLS_miss_slope_up_d_prime                                     0.080357
# DMS_hit_auc_d_prime                                           0.099647
# VS_hit_peak_timing_false_alarm_rate                          -0.101747
# DLS_hit_peak_timing_d_prime                                   0.115326
# DLS_mistake_slope_down_total_mistakes                        -0.159283
# VS_miss_slope_up_d_prime                                      0.085231
# DLS_reward_collect_auc_hit_rate                               0.115224
# DMS_hit_maximal_value_total_mistakes                          0.097945
# DLS_mistake_slope_down_false_alarm_rate                      -0.158047
# DMS_hit_maximal_value_hit_rate                                0.097759
# VS_hit_maximal_value_hit_rate                                 0.099686
# DLS_hit_peak_timing_total_hits                                0.112235
# DLS_reward_collect_peak_timing_c_score                       -0.111710
# VS_miss_peak_timing_d_prime                                  -0.080879
# VS_miss_peak_timing_total_hits                               -0.080720
# VS_hit_slope_up_participation                                 0.094969
# DMS_hit_maximal_value_c_score                                -0.092875
# VS_miss_maximal_value_false_alarm_rate                        0.079311
# VS_mistake_maximal_value_hit_rate                             0.118718
# DMS_cor_reject_slope_up_c_score                              -0.040426
# DLS_cor_reject_peak_timing_c_score                            0.042857
# DMS_hit_peak_timing_total_hits                               -0.091770
# DMS_miss_auc_c_score                                         -0.070629
# DMS_reward_collect_maximal_value_total_mistakes               0.090746
# DLS_cor_reject_slope_down_c_score                             0.042073
# DLS_hit_peak_timing_hit_rate                                  0.105694
# VS_miss_peak_timing_hit_rate                                 -0.076773
# DLS_reward_collect_auc_participation                          0.103840
# DLS_reward_collect_slope_up_false_alarm_rate                 -0.102489
# DLS_mistake_slope_up_false_alarm_rate                        -0.142255
# DLS_reward_collect_auc_c_score                               -0.101547
# DLS_mistake_slope_down_d_prime                                0.140150
# DLS_mistake_slope_up_total_mistakes                          -0.140755
# DLS_reward_collect_slope_up_total_mistakes                   -0.101106
# DLS_cor_reject_slope_up_false_alarm_rate                     -0.039851
# DMS_hit_maximal_value_false_alarm_rate                        0.084922
# DMS_cor_reject_slope_up_total_hits                            0.037082
# DLS_cor_reject_slope_up_total_mistakes                       -0.039506
# VS_miss_slope_down_total_hits                                -0.071764
# VS_hit_slope_down_c_score                                     0.084947
# DMS_mistake_maximal_value_false_alarm_rate                    0.110873
# DMS_miss_auc_d_prime                                          0.062645
# DMS_miss_slope_up_total_mistakes                              0.063182
# VS_reward_collect_slope_up_total_mistakes                     0.082808
# DMS_miss_slope_up_false_alarm_rate                            0.062789
# DMS_cor_reject_slope_up_hit_rate                              0.035154
# VS_mistake_slope_up_total_hits                               -0.105496
# DLS_hit_peak_timing_c_score                                  -0.093035
# DLS_hit_slope_down_d_prime                                    0.092872
# DMS_mistake_maximal_value_total_mistakes                      0.108085
# DMS_reward_collect_maximal_value_false_alarm_rate             0.078977
# VS_reward_collect_slope_down_participation                   -0.079417
# DLS_reward_collect_auc_d_prime                                0.090579
# DLS_cor_reject_peak_timing_participation                     -0.035755
# DMS_mistake_slope_up_d_prime                                 -0.101923
# DLS_miss_auc_d_prime                                         -0.058653
# DMS_hit_peak_timing_participation                            -0.073637
# DMS_cor_reject_slope_down_d_prime                            -0.031633
# VS_mistake_slope_up_hit_rate                                 -0.094555
# VS_miss_slope_down_hit_rate                                  -0.061391
# DMS_hit_peak_timing_d_prime                                  -0.071672
# VS_hit_peak_timing_d_prime                                   -0.072803
# DLS_mistake_maximal_value_total_hits                          0.115197
# DLS_miss_slope_up_total_hits                                  0.056436
# DMS_mistake_slope_up_hit_rate                                -0.097110
# VS_miss_slope_down_d_prime                                   -0.060012
# DLS_cor_reject_maximal_value_hit_rate                        -0.032589
# VS_reward_collect_slope_up_false_alarm_rate                   0.071375
# VS_mistake_auc_hit_rate                                       0.089278
# VS_hit_slope_down_participation                              -0.069777
# DLS_mistake_slope_up_c_score                                  0.110628
# DLS_hit_slope_up_false_alarm_rate                            -0.079205
# DLS_mistake_slope_up_participation                           -0.109404
# DLS_cor_reject_slope_down_hit_rate                           -0.031087
# DLS_reward_collect_slope_up_participation                    -0.078497
# DMS_cor_reject_slope_up_participation                         0.029222
# VS_mistake_slope_down_d_prime                                -0.085559
# DLS_hit_auc_hit_rate                                          0.077710
# DMS_cor_reject_auc_c_score                                   -0.028781
# DMS_mistake_slope_up_total_hits                              -0.091060
# DLS_hit_slope_up_total_mistakes                              -0.077448
# DLS_hit_auc_total_hits                                        0.076705
# DLS_hit_auc_d_prime                                           0.076589
# VS_miss_peak_timing_participation                            -0.055775
# DLS_reward_collect_slope_up_c_score                           0.076023
# DLS_mistake_slope_down_participation                         -0.103919
# DLS_hit_peak_timing_participation                             0.074349
# DMS_miss_slope_down_total_mistakes                           -0.049052
# DLS_mistake_slope_up_d_prime                                  0.103277
# VS_hit_slope_up_d_prime                                      -0.064091
# VS_cor_reject_slope_up_c_score                                0.029462
# DMS_miss_slope_down_participation                            -0.047430
# VS_cor_reject_maximal_value_hit_rate                         -0.028232
# DLS_miss_slope_down_total_mistakes                           -0.047924
# DMS_cor_reject_slope_down_total_hits                         -0.026111
# DLS_miss_slope_down_false_alarm_rate                         -0.047567
# VS_mistake_slope_up_d_prime                                  -0.078459
# VS_mistake_slope_up_c_score                                   0.078354
# DLS_miss_slope_up_hit_rate                                    0.047567
# DLS_mistake_slope_down_c_score                                0.096428
# VS_hit_auc_d_prime                                           -0.060710
# DMS_hit_peak_timing_hit_rate                                 -0.059153
# VS_miss_peak_timing_c_score                                   0.050452
# DLS_cor_reject_slope_up_total_hits                            0.027588
# DMS_mistake_peak_timing_hit_rate                              0.080286
# VS_mistake_maximal_value_d_prime                             -0.075291
# VS_reward_collect_slope_up_participation                      0.060063
# VS_miss_slope_down_c_score                                    0.049648
# DLS_hit_slope_up_c_score                                      0.067631
# DMS_cor_reject_peak_timing_total_mistakes                    -0.024832
# DLS_reward_collect_peak_timing_d_prime                       -0.066765
# DMS_mistake_slope_up_c_score                                  0.078057
# DLS_miss_slope_down_d_prime                                   0.044768
# DLS_hit_auc_c_score                                          -0.065698
# DMS_miss_slope_down_total_hits                               -0.042272
# VS_cor_reject_auc_c_score                                    -0.025134
# VS_reward_collect_peak_timing_d_prime                        -0.054955
# DLS_miss_auc_total_hits                                      -0.042508
# DMS_cor_reject_maximal_value_c_score                         -0.023214
# DMS_mistake_slope_down_total_mistakes                         0.073221
# DMS_mistake_maximal_value_participation                       0.072757
# VS_cor_reject_slope_up_hit_rate                              -0.024797
# DLS_hit_slope_up_participation                               -0.061341
# DLS_cor_reject_auc_total_mistakes                             0.024218
# DMS_mistake_slope_down_false_alarm_rate                       0.070998
# VS_mistake_peak_timing_c_score                               -0.066486
# DMS_mistake_slope_down_participation                          0.070892
# DLS_cor_reject_auc_false_alarm_rate                           0.023328
# DLS_hit_auc_participation                                     0.058687
# DMS_cor_reject_peak_timing_false_alarm_rate                  -0.021729
# VS_cor_reject_auc_participation                               0.023064
# DMS_mistake_peak_timing_c_score                              -0.067694
# VS_mistake_slope_up_participation                            -0.065031
# DMS_mistake_peak_timing_total_hits                            0.067556
# DLS_cor_reject_slope_down_total_hits                         -0.022904
# DMS_cor_reject_slope_down_hit_rate                           -0.021314
# DLS_miss_slope_up_c_score                                    -0.039116
# DMS_mistake_slope_up_participation                           -0.067061
# DMS_miss_slope_down_false_alarm_rate                         -0.037165
# DMS_mistake_maximal_value_c_score                            -0.065521
# DLS_miss_auc_hit_rate                                        -0.037731
# DMS_mistake_peak_timing_participation                         0.064912
# DLS_cor_reject_auc_d_prime                                   -0.021954
# DMS_reward_collect_maximal_value_d_prime                      0.047357
# VS_reward_collect_slope_up_d_prime                           -0.048300
# VS_cor_reject_slope_up_total_hits                            -0.022033
# VS_miss_auc_total_mistakes                                    0.039478
# DLS_mistake_peak_timing_d_prime                               0.074438
# DMS_mistake_maximal_value_d_prime                            -0.062517
# VS_mistake_slope_down_total_hits                             -0.057543
# VS_mistake_maximal_value_total_hits                           0.056360
# VS_cor_reject_auc_total_mistakes                              0.020074
# VS_hit_slope_up_c_score                                      -0.044198
# DMS_mistake_slope_down_hit_rate                               0.058883
# DMS_hit_peak_timing_c_score                                   0.042976
# VS_cor_reject_auc_false_alarm_rate                            0.019750
# VS_mistake_peak_timing_false_alarm_rate                       0.054418
# VS_mistake_peak_timing_participation                          0.054096
# DMS_cor_reject_auc_hit_rate                                   0.018235
# DMS_mistake_slope_down_c_score                               -0.057028
# VS_cor_reject_auc_total_hits                                  0.019262
# DLS_miss_maximal_value_hit_rate                              -0.032768
# DMS_mistake_peak_timing_false_alarm_rate                      0.056372
# DLS_reward_collect_slope_down_total_mistakes                  0.048151
# DLS_cor_reject_slope_up_hit_rate                              0.019124
# DMS_cor_reject_auc_false_alarm_rate                           0.017440
# VS_miss_slope_up_false_alarm_rate                            -0.034608
# DMS_mistake_slope_down_total_hits                             0.054645
# DLS_reward_collect_slope_down_false_alarm_rate                0.046450
# DLS_mistake_peak_timing_total_hits                            0.064279
# DMS_reward_collect_peak_timing_total_mistakes                -0.039637
# DLS_reward_collect_peak_timing_hit_rate                       0.046117
# DMS_miss_slope_down_c_score                                   0.030412
# VS_mistake_auc_total_hits                                     0.050253
# DLS_reward_collect_maximal_value_c_score                     -0.045749
# DMS_reward_collect_slope_down_d_prime                         0.039072
# VS_mistake_peak_timing_total_mistakes                         0.049459
# VS_mistake_peak_timing_hit_rate                               0.049310
# DLS_hit_slope_down_false_alarm_rate                           0.044943
# VS_cor_reject_auc_hit_rate                                    0.017811
# DMS_hit_peak_timing_total_mistakes                           -0.038314
# VS_mistake_slope_down_hit_rate                               -0.048918
# DMS_cor_reject_auc_d_prime                                    0.016521
# VS_cor_reject_slope_up_participation                         -0.018054
# DMS_miss_slope_down_hit_rate                                 -0.029363
# DLS_mistake_peak_timing_hit_rate                              0.061440
# VS_miss_slope_up_total_hits                                   0.032371
# VS_mistake_slope_down_total_mistakes                          0.047915
# VS_mistake_auc_d_prime                                       -0.047876
# DMS_mistake_peak_timing_d_prime                               0.051034
# DLS_mistake_auc_participation                                 0.060401
# DMS_mistake_peak_timing_total_mistakes                        0.050805
# DLS_miss_auc_c_score                                          0.029195
# VS_miss_slope_down_participation                             -0.031284
# VS_mistake_slope_down_false_alarm_rate                        0.046799
# DMS_cor_reject_maximal_value_total_hits                      -0.015652
# DMS_cor_reject_auc_participation                              0.015569
# DLS_hit_slope_down_total_mistakes                             0.041647
# VS_miss_auc_false_alarm_rate                                  0.030362
# DMS_mistake_maximal_value_hit_rate                            0.047326
# DMS_cor_reject_slope_down_participation                      -0.014975
# DMS_cor_reject_slope_up_false_alarm_rate                      0.015003
# DMS_cor_reject_auc_total_hits                                 0.014872
# DLS_mistake_slope_down_total_hits                             0.055537
# DMS_reward_collect_slope_up_participation                     0.033111
# VS_miss_slope_up_total_mistakes                              -0.028449
# DMS_cor_reject_auc_total_mistakes                             0.014107
# DMS_cor_reject_slope_down_c_score                             0.013985
# DMS_miss_slope_down_d_prime                                  -0.024946
# DLS_reward_collect_slope_up_d_prime                           0.037464
# DLS_reward_collect_maximal_value_participation                0.037178
# DMS_cor_reject_slope_up_total_mistakes                        0.013704
# DLS_mistake_auc_hit_rate                                      0.050139
# DMS_reward_collect_peak_timing_d_prime                        0.030824
# DLS_mistake_peak_timing_total_mistakes                       -0.049661
# DLS_reward_collect_slope_up_hit_rate                         -0.035881
# VS_miss_slope_up_hit_rate                                     0.026401
# DLS_miss_slope_up_participation                               0.024042
# DLS_miss_slope_up_total_mistakes                             -0.023870
# DMS_reward_collect_slope_up_total_hits                        0.029838
# DLS_miss_slope_up_false_alarm_rate                           -0.023546
# DMS_reward_collect_slope_up_total_mistakes                    0.029589
# VS_hit_slope_up_total_hits                                    0.029913
# DLS_mistake_peak_timing_false_alarm_rate                     -0.047341
# DLS_reward_collect_auc_false_alarm_rate                       0.034084
# DLS_reward_collect_auc_total_mistakes                         0.033626
# DLS_cor_reject_auc_c_score                                   -0.013235
# VS_reward_collect_slope_up_c_score                           -0.029222
# DMS_mistake_slope_up_false_alarm_rate                        -0.038966
# DMS_reward_collect_peak_timing_participation                 -0.028121
# VS_mistake_peak_timing_total_hits                             0.035247
# DLS_hit_maximal_value_participation                          -0.031903
# VS_cor_reject_slope_up_false_alarm_rate                      -0.012544
# DMS_reward_collect_slope_down_hit_rate                        0.026302
# VS_cor_reject_peak_timing_total_mistakes                     -0.012155
# VS_cor_reject_maximal_value_c_score                           0.012102
# DLS_mistake_auc_c_score                                      -0.041581
# DLS_hit_slope_up_hit_rate                                    -0.029657
# DLS_mistake_auc_total_hits                                    0.040816
# DLS_mistake_auc_false_alarm_rate                              0.040424
# DLS_mistake_auc_total_mistakes                                0.040189
# DMS_reward_collect_peak_timing_false_alarm_rate              -0.024252
# DMS_cor_reject_maximal_value_false_alarm_rate                 0.010462
# DMS_mistake_slope_up_total_mistakes                          -0.032712
# DLS_hit_slope_up_d_prime                                      0.027467
# DLS_reward_collect_slope_down_participation                   0.027357
# DLS_cor_reject_slope_down_d_prime                             0.010741
# DLS_miss_auc_total_mistakes                                   0.017953
# DLS_miss_auc_participation                                   -0.017874
# DLS_reward_collect_slope_down_d_prime                        -0.026023
# VS_miss_slope_down_total_mistakes                             0.018915
# DLS_reward_collect_peak_timing_total_hits                     0.025931
# DMS_hit_slope_down_d_prime                                   -0.021983
# DMS_hit_peak_timing_false_alarm_rate                         -0.021957
# DLS_miss_auc_false_alarm_rate                                 0.017073
# VS_cor_reject_slope_down_total_mistakes                       0.009659
# DLS_miss_slope_down_participation                            -0.016502
# VS_cor_reject_maximal_value_participation                     0.009487
# VS_miss_slope_down_false_alarm_rate                           0.017298
# VS_cor_reject_slope_down_false_alarm_rate                     0.009340
# DLS_reward_collect_slope_down_c_score                        -0.023547
# VS_miss_slope_up_c_score                                      0.017260
# DLS_miss_peak_timing_false_alarm_rate                        -0.015481
# DMS_cor_reject_maximal_value_participation                   -0.008242
# VS_hit_slope_down_total_mistakes                              0.019033
# DLS_mistake_slope_down_hit_rate                               0.029699
# DMS_hit_slope_down_false_alarm_rate                           0.018300
# VS_cor_reject_slope_up_total_mistakes                        -0.008640
# DLS_cor_reject_auc_participation                              0.008461
# DLS_miss_slope_down_total_hits                                0.014404
# DLS_miss_peak_timing_total_mistakes                          -0.014123
# DLS_reward_collect_slope_up_total_hits                       -0.020741
# VS_reward_collect_slope_down_false_alarm_rate                -0.017974
# DMS_reward_collect_slope_up_false_alarm_rate                  0.017260
# VS_hit_slope_down_false_alarm_rate                            0.017531
# VS_miss_peak_timing_total_mistakes                           -0.014317
# VS_cor_reject_slope_up_d_prime                               -0.007933
# VS_hit_slope_up_hit_rate                                      0.016634
# DMS_hit_maximal_value_d_prime                                 0.015832
# VS_cor_reject_peak_timing_false_alarm_rate                   -0.007138
# DMS_mistake_auc_false_alarm_rate                              0.020911
# DLS_cor_reject_auc_total_hits                                -0.006964
# DMS_mistake_maximal_value_total_hits                          0.020547
# VS_reward_collect_slope_up_total_hits                         0.015261
# DLS_hit_maximal_value_c_score                                 0.017301
# DLS_hit_slope_up_total_hits                                  -0.017341
# DMS_reward_collect_slope_down_c_score                        -0.014167
# DMS_hit_slope_down_total_mistakes                             0.013822
# DMS_mistake_auc_total_mistakes                                0.018704
# VS_miss_peak_timing_false_alarm_rate                         -0.011635
# DLS_cor_reject_auc_hit_rate                                  -0.006206
# DLS_cor_reject_slope_up_c_score                              -0.005802
# DLS_mistake_slope_up_total_hits                               0.019678
# DMS_reward_collect_peak_timing_total_hits                    -0.011995
# DMS_reward_collect_slope_down_total_hits                      0.011599
# DMS_reward_collect_slope_up_c_score                          -0.011430
# DMS_reward_collect_peak_timing_hit_rate                       0.011331
# DLS_mistake_maximal_value_hit_rate                            0.017716
# DMS_mistake_slope_down_d_prime                                0.014281
# VS_mistake_slope_down_c_score                                 0.012154
# DMS_hit_slope_down_total_hits                                -0.009326
# DMS_reward_collect_slope_down_total_mistakes                 -0.009198
# DLS_miss_slope_down_hit_rate                                  0.007134
# DMS_mistake_auc_d_prime                                      -0.012271
# DLS_hit_auc_false_alarm_rate                                  0.010307
# DMS_cor_reject_maximal_value_hit_rate                        -0.003797
# DLS_miss_slope_down_c_score                                   0.006896
# DMS_reward_collect_slope_up_hit_rate                          0.008312
# DMS_cor_reject_maximal_value_total_mistakes                   0.003375
# VS_reward_collect_slope_up_hit_rate                           0.007870
# DMS_cor_reject_slope_down_false_alarm_rate                    0.003268
# VS_mistake_slope_up_false_alarm_rate                         -0.009087
# DMS_mistake_auc_participation                                 0.009296
# DLS_mistake_slope_up_hit_rate                                -0.010936
# DMS_cor_reject_slope_down_total_mistakes                      0.002886
# DLS_cor_reject_slope_up_participation                        -0.003090
# DLS_hit_auc_total_mistakes                                    0.007723
# VS_reward_collect_slope_down_total_mistakes                  -0.006696
# DLS_hit_peak_timing_total_mistakes                           -0.006955
# DMS_mistake_auc_hit_rate                                      0.008084
# DLS_cor_reject_peak_timing_total_mistakes                     0.002731
# VS_mistake_slope_up_total_mistakes                           -0.007665
# DLS_mistake_peak_timing_c_score                              -0.008277
# DMS_cor_reject_maximal_value_d_prime                          0.002137
# DMS_hit_slope_down_c_score                                   -0.004769
# DLS_hit_peak_timing_false_alarm_rate                         -0.005531
# VS_mistake_peak_timing_d_prime                               -0.005777
# DMS_reward_collect_slope_up_d_prime                          -0.004276
# DMS_hit_slope_up_total_hits                                  -0.004242
# DLS_mistake_auc_d_prime                                      -0.006309
# DMS_reward_collect_peak_timing_c_score                        0.003744
# DLS_reward_collect_slope_down_total_hits                     -0.004361
# DMS_mistake_auc_c_score                                      -0.004694
# VS_miss_slope_up_participation                                0.002697
# DMS_hit_slope_up_d_prime                                     -0.003087
# DMS_hit_slope_up_participation                               -0.002889
# DMS_hit_slope_down_hit_rate                                   0.002500
# DMS_hit_slope_up_false_alarm_rate                             0.002138
# VS_cor_reject_auc_d_prime                                    -0.000987
# DLS_cor_reject_peak_timing_false_alarm_rate                   0.000968
# VS_reward_collect_auc_d_prime                                 0.002097
# DLS_cor_reject_maximal_value_total_hits                       0.000920
# DMS_hit_slope_down_participation                              0.001970
# DMS_mistake_auc_total_hits                                   -0.002656
# DLS_mistake_peak_timing_participation                        -0.003121
# DMS_reward_collect_slope_down_participation                   0.001809
# DMS_hit_slope_up_hit_rate                                     0.001653
# DLS_reward_collect_slope_down_hit_rate                       -0.001440
# DLS_miss_maximal_value_total_hits                            -0.000822
# DMS_hit_slope_up_c_score                                     -0.000980
# DMS_hit_slope_up_total_mistakes                              -0.000808
# VS_mistake_slope_down_participation                           0.000903
# DMS_reward_collect_slope_down_false_alarm_rate               -0.000703
#
#                                                         P-Value  \
# Metric Pair
# DLS_cor_reject_maximal_value_false_alarm_rate      4.994553e-43
# DLS_cor_reject_maximal_value_total_mistakes        5.072863e-42
# VS_hit_maximal_value_total_mistakes                3.091268e-20
# DLS_mistake_maximal_value_false_alarm_rate         3.831809e-19
# DLS_mistake_maximal_value_total_mistakes           5.854674e-19
# VS_reward_collect_maximal_value_total_mistakes     3.239629e-18
# VS_hit_maximal_value_false_alarm_rate              3.904935e-17
# VS_reward_collect_peak_timing_participation        5.231153e-17
# DLS_cor_reject_maximal_value_d_prime               5.936047e-16
# VS_reward_collect_maximal_value_false_alarm_rate   3.118954e-15
# DLS_hit_maximal_value_d_prime                      1.308377e-14
# DLS_miss_maximal_value_false_alarm_rate            1.608281e-14
# DLS_miss_maximal_value_total_mistakes              2.966284e-14
# VS_hit_maximal_value_participation                 7.849709e-14
# VS_reward_collect_peak_timing_c_score              9.203192e-14
# VS_reward_collect_peak_timing_total_hits           2.232730e-13
# VS_reward_collect_maximal_value_participation      2.424896e-13
# DLS_cor_reject_maximal_value_participation         4.110867e-13
# DMS_reward_collect_auc_total_hits                  7.047586e-13
# DLS_mistake_maximal_value_d_prime                  2.520475e-12
# DMS_reward_collect_auc_hit_rate                    1.622321e-11
# VS_miss_maximal_value_total_hits                   3.593340e-11
# VS_reward_collect_peak_timing_hit_rate             5.398175e-11
# VS_miss_auc_total_hits                             6.287686e-11
# VS_reward_collect_peak_timing_total_mistakes       6.572542e-11
# VS_miss_maximal_value_hit_rate                     2.164185e-10
# DMS_reward_collect_auc_participation               2.319341e-10
# DMS_reward_collect_auc_c_score                     2.772804e-10
# VS_hit_auc_participation                           5.256113e-10
# DLS_mistake_maximal_value_participation            6.039204e-10
# DMS_hit_auc_c_score                                6.450540e-10
# VS_hit_auc_total_mistakes                          7.840194e-10
# DLS_hit_maximal_value_total_mistakes               9.365894e-10
# DLS_hit_maximal_value_false_alarm_rate             9.706364e-10
# DLS_reward_collect_maximal_value_d_prime           1.167286e-09
# VS_reward_collect_peak_timing_false_alarm_rate     1.883872e-09
# DMS_hit_auc_participation                          2.476975e-09
# DMS_hit_auc_total_hits                             4.997748e-09
# DMS_hit_auc_hit_rate                               6.119549e-09
# VS_cor_reject_slope_down_total_hits                6.998164e-09
# DLS_mistake_maximal_value_c_score                  1.019365e-08
# VS_cor_reject_slope_down_d_prime                   1.307152e-08
# VS_mistake_maximal_value_false_alarm_rate          1.765020e-08
# VS_miss_maximal_value_participation                1.858934e-08
# VS_miss_auc_hit_rate                               1.892782e-08
# DMS_miss_peak_timing_participation                 1.901278e-08
# VS_hit_maximal_value_c_score                       2.432879e-08
# VS_mistake_maximal_value_total_mistakes            2.716233e-08
# VS_miss_maximal_value_d_prime                      3.019091e-08
# DMS_miss_peak_timing_c_score                       4.132588e-08
# VS_reward_collect_maximal_value_c_score            5.987172e-08
# VS_hit_auc_false_alarm_rate                        5.997651e-08
# DMS_miss_maximal_value_hit_rate                    6.001347e-08
# DMS_miss_peak_timing_total_hits                    7.707452e-08
# DLS_cor_reject_maximal_value_c_score               8.500933e-08
# DMS_miss_maximal_value_participation               1.042911e-07
# DMS_miss_maximal_value_c_score                     1.058423e-07
# DMS_miss_peak_timing_total_mistakes                1.690895e-07
# VS_miss_auc_d_prime                                1.741827e-07
# DMS_miss_maximal_value_total_hits                  1.799068e-07
# DMS_miss_peak_timing_hit_rate                      2.344405e-07
# VS_cor_reject_slope_down_hit_rate                  3.502291e-07
# VS_cor_reject_peak_timing_total_hits               3.633591e-07
# DMS_miss_peak_timing_false_alarm_rate              4.036046e-07
# VS_cor_reject_peak_timing_d_prime                  4.125234e-07
# DMS_reward_collect_auc_d_prime                     8.094775e-07
# VS_hit_auc_c_score                                 1.026979e-06
# VS_reward_collect_auc_participation                1.084011e-06
# DMS_miss_maximal_value_false_alarm_rate            1.194807e-06
# VS_hit_peak_timing_participation                   1.350400e-06
# DMS_hit_auc_total_mistakes                         1.568982e-06
# VS_hit_peak_timing_total_hits                      1.954071e-06
# DMS_hit_auc_false_alarm_rate                       1.964305e-06
# DMS_miss_maximal_value_total_mistakes              2.132676e-06
# DLS_miss_maximal_value_d_prime                     2.461790e-06
# DMS_miss_maximal_value_d_prime                     2.653030e-06
# VS_miss_auc_participation                          4.306380e-06
# VS_mistake_maximal_value_participation             5.418225e-06
# VS_miss_maximal_value_c_score                      6.822672e-06
# DLS_miss_peak_timing_d_prime                       8.438282e-06
# VS_cor_reject_peak_timing_hit_rate                 9.448974e-06
# DLS_reward_collect_maximal_value_total_hits        9.909585e-06
# DLS_hit_maximal_value_total_hits                   1.402451e-05
# VS_cor_reject_maximal_value_total_mistakes         1.525341e-05
# VS_cor_reject_maximal_value_false_alarm_rate       1.808047e-05
# DMS_miss_peak_timing_d_prime                       2.229740e-05
# DLS_miss_peak_timing_total_hits                    2.454778e-05
# VS_mistake_maximal_value_c_score                   2.592133e-05
# DLS_reward_collect_peak_timing_total_mistakes      2.690816e-05
# DLS_reward_collect_peak_timing_false_alarm_rate    2.801943e-05
# VS_miss_auc_c_score                                3.317534e-05
# VS_hit_auc_total_hits                              4.125879e-05
# DLS_miss_maximal_value_participation               4.415694e-05
# DMS_reward_collect_auc_total_mistakes              4.560702e-05
# VS_cor_reject_maximal_value_d_prime                4.878401e-05
# VS_hit_peak_timing_hit_rate                        4.928482e-05
# VS_reward_collect_auc_total_mistakes               5.093370e-05
# VS_reward_collect_auc_total_hits                   5.411643e-05
# DMS_cor_reject_peak_timing_d_prime                 5.822255e-05
# VS_reward_collect_slope_down_hit_rate              6.038619e-05
# VS_hit_maximal_value_d_prime                       6.313659e-05
# DMS_reward_collect_maximal_value_total_hits        6.611646e-05
# DLS_miss_peak_timing_hit_rate                      7.433735e-05
# DLS_cor_reject_slope_down_false_alarm_rate         7.751402e-05
# DMS_cor_reject_peak_timing_total_hits              7.956242e-05
# DMS_reward_collect_auc_false_alarm_rate            8.045888e-05
# VS_hit_slope_down_total_hits                       8.720372e-05
# VS_reward_collect_auc_c_score                      8.919445e-05
# DLS_cor_reject_slope_down_total_mistakes           1.039491e-04
# VS_hit_slope_down_d_prime                          1.144690e-04
# VS_reward_collect_slope_down_d_prime               1.402443e-04
# VS_cor_reject_slope_down_c_score                   1.529272e-04
# DMS_miss_slope_up_d_prime                          1.732909e-04
# VS_hit_peak_timing_c_score                         1.787316e-04
# DLS_cor_reject_peak_timing_d_prime                 1.838549e-04
# DMS_miss_slope_up_total_hits                       1.925172e-04
# DMS_reward_collect_maximal_value_participation     2.153779e-04
# DLS_reward_collect_maximal_value_hit_rate          2.642444e-04
# VS_reward_collect_slope_down_total_hits            2.993106e-04
# VS_mistake_auc_false_alarm_rate                    3.582539e-04
# DMS_miss_slope_up_hit_rate                         4.008413e-04
# VS_hit_slope_up_total_mistakes                     4.272277e-04
# DMS_hit_maximal_value_participation                4.608218e-04
# VS_reward_collect_auc_false_alarm_rate             4.933231e-04
# DLS_reward_collect_maximal_value_false_alarm_rate  5.487832e-04
# DMS_hit_maximal_value_total_hits                   5.511564e-04
# DLS_reward_collect_maximal_value_total_mistakes    5.619931e-04
# VS_cor_reject_peak_timing_participation            5.705629e-04
# VS_hit_slope_down_hit_rate                         5.764945e-04
# DLS_cor_reject_peak_timing_total_hits              5.774837e-04
# VS_mistake_auc_total_mistakes                      6.568505e-04
# VS_reward_collect_maximal_value_d_prime            7.445618e-04
# ...
# DLS_miss_auc_hit_rate                                               1302
# DMS_mistake_peak_timing_participation                                439
# DLS_cor_reject_auc_d_prime                                          3805
# DMS_reward_collect_maximal_value_d_prime                             818
# VS_reward_collect_slope_up_d_prime                                   781
# VS_cor_reject_slope_up_total_hits                                   3650
# VS_miss_auc_total_mistakes                                          1124
# DLS_mistake_peak_timing_d_prime                                      313
# DMS_mistake_maximal_value_d_prime                                    439
# VS_mistake_slope_down_total_hits                                     499
# VS_mistake_maximal_value_total_hits                                  499
# VS_cor_reject_auc_total_mistakes                                    3799
# VS_hit_slope_up_c_score                                              785
# DMS_mistake_slope_down_hit_rate                                      439
# DMS_hit_peak_timing_c_score                                          820
# VS_cor_reject_auc_false_alarm_rate                                  3799
# VS_mistake_peak_timing_false_alarm_rate                              499
# VS_mistake_peak_timing_participation                                 499
# DMS_cor_reject_auc_hit_rate                                         4359
# DMS_mistake_slope_down_c_score                                       439
# VS_cor_reject_auc_total_hits                                        3799
# DLS_miss_maximal_value_hit_rate                                     1302
# DMS_mistake_peak_timing_false_alarm_rate                             439
# DLS_reward_collect_slope_down_total_mistakes                         598
# DLS_cor_reject_slope_up_hit_rate                                    3736
# DMS_cor_reject_auc_false_alarm_rate                                 4359
# VS_miss_slope_up_false_alarm_rate                                   1095
# DMS_mistake_slope_down_total_hits                                    439
# DLS_reward_collect_slope_down_false_alarm_rate                       598
# DLS_mistake_peak_timing_total_hits                                   313
# DMS_reward_collect_peak_timing_total_mistakes                        818
# DLS_reward_collect_peak_timing_hit_rate                              598
# DMS_miss_slope_down_c_score                                         1371
# VS_mistake_auc_total_hits                                            499
# DLS_reward_collect_maximal_value_c_score                             598
# DMS_reward_collect_slope_down_d_prime                                818
# VS_mistake_peak_timing_total_mistakes                                499
# VS_mistake_peak_timing_hit_rate                                      499
# DLS_hit_slope_down_false_alarm_rate                                  599
# VS_cor_reject_auc_hit_rate                                          3799
# DMS_hit_peak_timing_total_mistakes                                   820
# VS_mistake_slope_down_hit_rate                                       499
# DMS_cor_reject_auc_d_prime                                          4359
# VS_cor_reject_slope_up_participation                                3650
# DMS_miss_slope_down_hit_rate                                        1371
# DLS_mistake_peak_timing_hit_rate                                     313
# VS_miss_slope_up_total_hits                                         1095
# VS_mistake_slope_down_total_mistakes                                 499
# VS_mistake_auc_d_prime                                               499
# DMS_mistake_peak_timing_d_prime                                      439
# DLS_mistake_auc_participation                                        313
# DMS_mistake_peak_timing_total_mistakes                               439
# DLS_miss_auc_c_score                                                1302
# VS_miss_slope_down_participation                                    1124
# VS_mistake_slope_down_false_alarm_rate                               499
# DMS_cor_reject_maximal_value_total_hits                             4359
# DMS_cor_reject_auc_participation                                    4359
# DLS_hit_slope_down_total_mistakes                                    599
# VS_miss_auc_false_alarm_rate                                        1124
# DMS_mistake_maximal_value_hit_rate                                   439
# DMS_cor_reject_slope_down_participation                             4359
# DMS_cor_reject_slope_up_false_alarm_rate                            4288
# DMS_cor_reject_auc_total_hits                                       4359
# DLS_mistake_slope_down_total_hits                                    313
# DMS_reward_collect_slope_up_participation                            812
# VS_miss_slope_up_total_mistakes                                     1095
# DMS_cor_reject_auc_total_mistakes                                   4359
# DMS_cor_reject_slope_down_c_score                                   4359
# DMS_miss_slope_down_d_prime                                         1371
# DLS_reward_collect_slope_up_d_prime                                  596
# DLS_reward_collect_maximal_value_participation                       598
# DMS_cor_reject_slope_up_total_mistakes                              4288
# DLS_mistake_auc_hit_rate                                             313
# DMS_reward_collect_peak_timing_d_prime                               818
# DLS_mistake_peak_timing_total_mistakes                               313
# DLS_reward_collect_slope_up_hit_rate                                 596
# VS_miss_slope_up_hit_rate                                           1095
# DLS_miss_slope_up_participation                                     1285
# DLS_miss_slope_up_total_mistakes                                    1285
# DMS_reward_collect_slope_up_total_hits                               812
# DLS_miss_slope_up_false_alarm_rate                                  1285
# DMS_reward_collect_slope_up_total_mistakes                           812
# VS_hit_slope_up_total_hits                                           785
# DLS_mistake_peak_timing_false_alarm_rate                             313
# DLS_reward_collect_auc_false_alarm_rate                              598
# DLS_reward_collect_auc_total_mistakes                                598
# DLS_cor_reject_auc_c_score                                          3805
# VS_reward_collect_slope_up_c_score                                   781
# DMS_mistake_slope_up_false_alarm_rate                                434
# DMS_reward_collect_peak_timing_participation                         818
# VS_mistake_peak_timing_total_hits                                    499
# DLS_hit_maximal_value_participation                                  599
# VS_cor_reject_slope_up_false_alarm_rate                             3650
# DMS_reward_collect_slope_down_hit_rate                               818
# VS_cor_reject_peak_timing_total_mistakes                            3799
# VS_cor_reject_maximal_value_c_score                                 3799
# DLS_mistake_auc_c_score                                              313
# DLS_hit_slope_up_hit_rate                                            596
# DLS_mistake_auc_total_hits                                           313
# DLS_mistake_auc_false_alarm_rate                                     313
# DLS_mistake_auc_total_mistakes                                       313
# DMS_reward_collect_peak_timing_false_alarm_rate                      818
# DMS_cor_reject_maximal_value_false_alarm_rate                       4359
# DMS_mistake_slope_up_total_mistakes                                  434
# DLS_hit_slope_up_d_prime                                             596
# DLS_reward_collect_slope_down_participation                          598
# DLS_cor_reject_slope_down_d_prime                                   3805
# DLS_miss_auc_total_mistakes                                         1302
# DLS_miss_auc_participation                                          1302
# DLS_reward_collect_slope_down_d_prime                                598
# VS_miss_slope_down_total_mistakes                                   1124
# DLS_reward_collect_peak_timing_total_hits                            598
# DMS_hit_slope_down_d_prime                                           820
# DMS_hit_peak_timing_false_alarm_rate                                 820
# DLS_miss_auc_false_alarm_rate                                       1302
# VS_cor_reject_slope_down_total_mistakes                             3799
# DLS_miss_slope_down_participation                                   1302
# VS_cor_reject_maximal_value_participation                           3799
# VS_miss_slope_down_false_alarm_rate                                 1124
# VS_cor_reject_slope_down_false_alarm_rate                           3799
# DLS_reward_collect_slope_down_c_score                                598
# VS_miss_slope_up_c_score                                            1095
# DLS_miss_peak_timing_false_alarm_rate                               1302
# DMS_cor_reject_maximal_value_participation                          4359
# VS_hit_slope_down_total_mistakes                                     786
# DLS_mistake_slope_down_hit_rate                                      313
# DMS_hit_slope_down_false_alarm_rate                                  820
# VS_cor_reject_slope_up_total_mistakes                               3650
# DLS_cor_reject_auc_participation                                    3805
# DLS_miss_slope_down_total_hits                                      1302
# DLS_miss_peak_timing_total_mistakes                                 1302
# DLS_reward_collect_slope_up_total_hits                               596
# VS_reward_collect_slope_down_false_alarm_rate                        784
# DMS_reward_collect_slope_up_false_alarm_rate                         812
# VS_hit_slope_down_false_alarm_rate                                   786
# VS_miss_peak_timing_total_mistakes                                  1124
# VS_cor_reject_slope_up_d_prime                                      3650
# VS_hit_slope_up_hit_rate                                             785
# DMS_hit_maximal_value_d_prime                                        820
# VS_cor_reject_peak_timing_false_alarm_rate                          3799
# DMS_mistake_auc_false_alarm_rate                                     439
# DLS_cor_reject_auc_total_hits                                       3805
# DMS_mistake_maximal_value_total_hits                                 439
# VS_reward_collect_slope_up_total_hits                                781
# DLS_hit_maximal_value_c_score                                        599
# DLS_hit_slope_up_total_hits                                          596
# DMS_reward_collect_slope_down_c_score                                818
# DMS_hit_slope_down_total_mistakes                                    820
# DMS_mistake_auc_total_mistakes                                       439
# VS_miss_peak_timing_false_alarm_rate                                1124
# DLS_cor_reject_auc_hit_rate                                         3805
# DLS_cor_reject_slope_up_c_score                                     3736
# DLS_mistake_slope_up_total_hits                                      308
# DMS_reward_collect_peak_timing_total_hits                            818
# DMS_reward_collect_slope_down_total_hits                             818
# DMS_reward_collect_slope_up_c_score                                  812
# DMS_reward_collect_peak_timing_hit_rate                              818
# DLS_mistake_maximal_value_hit_rate                                   313
# DMS_mistake_slope_down_d_prime                                       439
# VS_mistake_slope_down_c_score                                        499
# DMS_hit_slope_down_total_hits                                        820
# DMS_reward_collect_slope_down_total_mistakes                         818
# DLS_miss_slope_down_hit_rate                                        1302
# DMS_mistake_auc_d_prime                                              439
# DLS_hit_auc_false_alarm_rate                                         599
# DMS_cor_reject_maximal_value_hit_rate                               4359
# DLS_miss_slope_down_c_score                                         1302
# DMS_reward_collect_slope_up_hit_rate                                 812
# DMS_cor_reject_maximal_value_total_mistakes                         4359
# VS_reward_collect_slope_up_hit_rate                                  781
# DMS_cor_reject_slope_down_false_alarm_rate                          4359
# VS_mistake_slope_up_false_alarm_rate                                 475
# DMS_mistake_auc_participation                                        439
# DLS_mistake_slope_up_hit_rate                                        308
# DMS_cor_reject_slope_down_total_mistakes                            4359
# DLS_cor_reject_slope_up_participation                               3736
# DLS_hit_auc_total_mistakes                                           599
# VS_reward_collect_slope_down_total_mistakes                          784
# DLS_hit_peak_timing_total_mistakes                                   599
# DMS_mistake_auc_hit_rate                                             439
# DLS_cor_reject_peak_timing_total_mistakes                           3805
# VS_mistake_slope_up_total_mistakes                                   475
# DLS_mistake_peak_timing_c_score                                      313
# DMS_cor_reject_maximal_value_d_prime                                4359
# DMS_hit_slope_down_c_score                                           820
# DLS_hit_peak_timing_false_alarm_rate                                 599
# VS_mistake_peak_timing_d_prime                                       499
# DMS_reward_collect_slope_up_d_prime                                  812
# DMS_hit_slope_up_total_hits                                          816
# DLS_mistake_auc_d_prime                                              313
# DMS_reward_collect_peak_timing_c_score                               818
# DLS_reward_collect_slope_down_total_hits                             598
# DMS_mistake_auc_c_score                                              439
# VS_miss_slope_up_participation                                      1095
# DMS_hit_slope_up_d_prime                                             816
# DMS_hit_slope_up_participation                                       816
# DMS_hit_slope_down_hit_rate                                          820
# DMS_hit_slope_up_false_alarm_rate                                    816
# VS_cor_reject_auc_d_prime                                           3799
# DLS_cor_reject_peak_timing_false_alarm_rate                         3805
# VS_reward_collect_auc_d_prime                                        784
# DLS_cor_reject_maximal_value_total_hits                             3805
# DMS_hit_slope_down_participation                                     820
# DMS_mistake_auc_total_hits                                           439
# DLS_mistake_peak_timing_participation                                313
# DMS_reward_collect_slope_down_participation                          818
# DMS_hit_slope_up_hit_rate                                            816
# DLS_reward_collect_slope_down_hit_rate                               598
# DLS_miss_maximal_value_total_hits                                   1302
# DMS_hit_slope_up_c_score                                             816
# DMS_hit_slope_up_total_mistakes                                      816
# VS_mistake_slope_down_participation                                  499
# DMS_reward_collect_slope_down_false_alarm_rate                       818
